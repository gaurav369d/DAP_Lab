# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav369d/DAP_Lab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
a = input("Enter the number")
print(a)
# Out:
# Hello World
# Enter the number45
# 45
